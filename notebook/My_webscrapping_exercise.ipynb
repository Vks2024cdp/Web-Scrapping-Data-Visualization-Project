# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import urllib3
import datetime
import csv

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36"
}

def get_all_products(url):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    
    # Find all product containers
    products = soup.find_all("div", class_="product-item-details")

    product_list = []

    for product in products:
        # Extract product name
        name_tag = product.select_one("h3.product-item-name a")
        product_name = name_tag.get_text(strip=True) if name_tag else "No name found"
        
        # Extract special price
        special_price_tag = product.select_one('span[id^="product-price-"] .price')
        special_price = special_price_tag.get_text(strip=True) if special_price_tag else "No price found"

        # Extract old price (if available)
        old_price_tag = product.select_one('span[id^="old-price-"] .price')
        old_price = old_price_tag.get_text(strip=True) if old_price_tag else "N/A"

        # Extract discount (if available)
        discount_tag = product.select_one(".price-save-amount")
        discount = discount_tag.get_text(strip=True) if discount_tag else "No discount"

        product_list.append({
            "Name": product_name,
            "Special Price": special_price,
            "Old Price": old_price,
            "Discount": discount
        })

    return product_list

# Example category or search page URL (replace with actual URL)
courts_url = "https://www.courts.com.sg/clearance?product_list_limit=40"

products = get_all_products(courts_url)

# Print results
for product in products:
    print(product)
# Out:
# {'Name': 'LOGITECH 910-006765 LOGITECH M100R USB WIRED MOUSE BLK CARTON BOX 3Y', 'Special Price': 'S$9.00', 'Old Price': 'S$12.00', 'Discount': '(save 25%)'}
# {'Name': 'CANON GI-790 PBK BLACK INK BOTTLE', 'Special Price': 'S$14.70', 'Old Price': 'S$15.00', 'Discount': '(save 2%)'}
# {'Name': 'CANON GI-790 C CYAN INK BOTTLE', 'Special Price': 'S$14.70', 'Old Price': 'S$15.00', 'Discount': '(save 2%)'}
# {'Name': 'LOGITECH 910-005934 PICO UNIFYING RECEIVER [CARTON PACK] (1Y)', 'Special Price': 'S$14.00', 'Old Price': 'S$16.00', 'Discount': '(save 12%)'}
# {'Name': 'MORRIES MS-1228S DRY IRON', 'Special Price': 'S$18.00', 'Old Price': 'S$20.30', 'Discount': '(save 11%)'}
# {'Name': 'ASUS TUF GAMING P1 GAMING MOUSEMAT TUF GAMING P1 GAMING MOUSEMAT', 'Special Price': 'S$16.00', 'Old Price': 'S$19.00', 'Discount': '(save 15%)'}
# {'Name': 'CORNELL CJKS10L CORDLESS KETTLE (1L)', 'Special Price': 'S$16.00', 'Old Price': 'S$33.90', 'Discount': '(save 52%)'}
# {'Name': 'MASTERPLUG SWC62N-MPA 13A 6 GANG INDIVIDUAL SWITCH (2M)', 'Special Price': 'S$18.00', 'Old Price': 'S$19.90', 'Discount': '(save 9%)'}
# {'Name': 'SAMSUNG MUF-128AB/APC SAMSUNG FIT PLUS USB FLASH DRIVE - 128GB', 'Special Price': 'S$27.00', 'Old Price': 'S$40.00', 'Discount': '(save 32%)'}
# {'Name': 'MASTERPLUG SRGU42N-MPA 13A 4 GANG INDIVIDUAL W/SURGE (WHITE)', 'Special Price': 'S$21.00', 'Old Price': 'S$22.90', 'Discount': '(save 8%)'}
# {'Name': 'ELECOM M-TM10DBPN WIRELESS FLAT SHAPE 4 BUTTON BLUE LED PN', 'Special Price': 'S$28.50', 'Old Price': 'S$29.90', 'Discount': '(save 4%)'}
# {'Name': 'MASTERPLUG SRGU62N-MPA 13A 6 GANG INDIVIDUAL W/SURGE (WHITE)', 'Special Price': 'S$23.00', 'Old Price': 'S$24.90', 'Discount': '(save 7%)'}
# {'Name': 'ELECOM MPA-CLL12BK TYPE C-LIGHTNING CABLE PD 1.2M L SHAPED ANTI BACTERIAL BLACK', 'Special Price': 'S$21.41', 'Old Price': 'S$24.90', 'Discount': '(save 14%)'}
# {'Name': 'LOGITECH 981-0000587 STEREO HEADSET H151 (SINGLE 3.5MM JACK)', 'Special Price': 'S$22.00', 'Old Price': 'S$25.00', 'Discount': '(save 12%)'}
# {'Name': 'CORNELL CSIS1601S STEAM IRON (1600W)', 'Special Price': 'S$23.00', 'Old Price': 'S$69.00', 'Discount': '(save 66%)'}
# {'Name': 'LOGITECH 956-000032 DESK MAT STUDIO SERIES - LAVENDER', 'Special Price': 'S$24.00', 'Old Price': 'S$39.00', 'Discount': '(save 38%)'}
# {'Name': 'LOGITECH 956-000045 DESK MAT STUDIO SERIES - DARKER ROSE', 'Special Price': 'S$24.00', 'Old Price': 'S$39.00', 'Discount': '(save 38%)'}
# {'Name': 'LOGITECH 956-000046 DESK MAT STUDIO SERIES - MID GREY', 'Special Price': 'S$24.00', 'Old Price': 'S$39.00', 'Discount': '(save 38%)'}
# {'Name': 'MASTERPLUG SRGLSU43PW-MPA 13A 4 GANG IND W/SURGE AND USB (3M)', 'Special Price': 'S$28.00', 'Old Price': 'S$34.90', 'Discount': '(save 19%)'}
# {'Name': 'JISULIFE LIFE9-3600 BLACK HANDHELD FAN LIFE9 (3600MAH)', 'Special Price': 'S$27.00', 'Old Price': 'S$30.90', 'Discount': '(save 12%)'}
# {'Name': 'CORNELL CJKE150SSW CORDLESS KETTLE 1.5L (WHITE)', 'Special Price': 'S$28.00', 'Old Price': 'S$79.00', 'Discount': '(save 64%)'}
# {'Name': 'LOGITECH G203 LIGHTSYNC RGB WIRED MOUSE BLACK (2Y)', 'Special Price': 'S$30.00', 'Old Price': 'S$32.90', 'Discount': '(save 8%)'}
# {'Name': 'LOGITECH G203 LIGHTSYNC RGB WIRED MOUSE WHITE (2Y)', 'Special Price': 'S$28.00', 'Old Price': 'S$32.90', 'Discount': '(save 14%)'}
# {'Name': 'CORNELL CBLS400BK BLENDER / GRINDER', 'Special Price': 'S$29.00', 'Old Price': 'S$69.90', 'Discount': '(save 58%)'}
# {'Name': 'CANON CLI-781 Y XL YELLOW XL INKJET CARTRIDGES', 'Special Price': 'S$34.69', 'Old Price': 'S$36.00', 'Discount': '(save 3%)'}
# {'Name': 'LOGITECH 940-000112 GAMEPAD F310', 'Special Price': 'S$30.00', 'Old Price': 'S$35.00', 'Discount': '(save 14%)'}
# {'Name': 'LOGITECH 910-006986 PEBBLE MOUSE 2 M350S - TONAL WHITE', 'Special Price': 'S$35.00', 'Old Price': 'S$49.00', 'Discount': '(save 28%)'}
# {'Name': 'LOGITECH 910-006987 PEBBLE MOUSE 2 M350S - TONAL ROSE', 'Special Price': 'S$35.00', 'Old Price': 'S$49.00', 'Discount': '(save 28%)'}
# {'Name': 'CORNELL CJKP182SSB CORDLESS KETTLE 1.8L (BLACK)', 'Special Price': 'S$34.00', 'Old Price': 'S$89.00', 'Discount': '(save 61%)'}
# {'Name': 'MORRIES MS-312TF 12 INCH TABLE FAN', 'Special Price': 'S$31.00', 'Old Price': 'S$38.60', 'Discount': '(save 19%)'}
# {'Name': 'MISTRAL ELECTRIC TABLE FAN (12 INCH) MTF1217SE (WINTER GREY)', 'Special Price': 'S$39.00', 'Old Price': 'S$49.00', 'Discount': '(save 20%)'}
# {'Name': 'MKE170M2ADKH 1.7L KETTLE (BLACK COLOR)', 'Special Price': 'S$36.00', 'Old Price': 'S$49.00', 'Discount': '(save 26%)'}
# {'Name': 'MIDEA MFT060M0APBH 6 INCH AIR CIRCULATION FAN', 'Special Price': 'S$36.00', 'Old Price': 'S$49.00', 'Discount': '(save 26%)'}
# {'Name': 'KENWOOD CH180 CHOPPER', 'Special Price': 'S$38.00', 'Old Price': 'S$39.90', 'Discount': '(save 4%)'}
# {'Name': 'RAZER RZ02-03820200-R3M1 HARD GAMING MOUSE MAT -  LARGE SPHEX V3', 'Special Price': 'S$34.00', 'Old Price': 'S$39.90', 'Discount': '(save 14%)'}
# {'Name': 'INNERGIE ADP-65DW DZDA 65W LAPTOP ADAPTOR FOR DELL', 'Special Price': 'S$36.00', 'Old Price': 'S$39.90', 'Discount': '(save 9%)'}
# {'Name': 'INNERGIE ADP-65DW DZDC 65W LAPTOP ADAPTOR FOR LENOVO', 'Special Price': 'S$36.00', 'Old Price': 'S$39.90', 'Discount': '(save 9%)'}
# {'Name': 'SONY WI-C100/BZE WIRELESS IN-EAR HEADPHONES (BLACK)', 'Special Price': 'S$38.40', 'Old Price': 'S$80.00', 'Discount': '(save 52%)'}
# {'Name': 'SONY WI-C100/WZE WIRELESS IN-EAR HEADPHONES (WHITE)', 'Special Price': 'S$38.40', 'Old Price': 'S$80.00', 'Discount': '(save 52%)'}
# {'Name': 'TARGUS APS1101AP-50 TARGUS SMART SURGE 6 WITH 4 USB PORTS (UK)', 'Special Price': 'S$37.00', 'Old Price': 'S$40.30', 'Discount': '(save 8%)'}

# %%
import requests
from bs4 import BeautifulSoup

# Base URL (pagination parameter `p` is appended later)
BASE_URL = "https://www.courts.com.sg/clearance?p={}&product_list_limit=40"

# Total pages (hardcoded)
TOTAL_PAGES = 23

# Headers to simulate a real browser request
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}

# List to store extracted product data
products_list = []

# Function to extract product data from a page
def extract_products(page_soup):
    products = page_soup.find_all("div", class_="product-item-details")
    for product in products:
        try:
            # Extract product name
            name_tag = product.find("h3", class_="product-item-name")
            name = name_tag.get_text(strip=True) if name_tag else "N/A"
            
            # Extract price
            price_tag = product.find("span", {"data-price-type": "finalPrice"})
            price = price_tag.get_text(strip=True) if price_tag else "N/A"
            
            # Extract old price (if available)
            old_price_tag = product.find("span", {"data-price-type": "oldPrice"})
            old_price = old_price_tag.get_text(strip=True) if old_price_tag else "N/A"
            
            # Calculate discount (if old price exists)
            discount = "N/A"
            if old_price != "N/A" and price != "N/A":
                old_price_value = float(old_price.replace("S$", "").replace(",", ""))
                price_value = float(price.replace("S$", "").replace(",", ""))
                discount = f"{round(((old_price_value - price_value) / old_price_value) * 100, 2)}%" if old_price_value > price_value else "0%"

            # Append extracted data
            products_list.append([name, price, old_price, discount])

        except Exception as e:
            print(f"Error extracting product: {e}")

# Loop through all 23 pages
for page in range(1, TOTAL_PAGES + 1):
    print(f"Scraping page {page}/{TOTAL_PAGES}...")
    url = BASE_URL.format(page)
    response = requests.get(url, headers=HEADERS)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        extract_products(soup)
    else:
        print(f"Failed to retrieve page {page}, status code: {response.status_code}")

# Save data to CSV
csv_filename = "courts_products.csv"
with open(csv_filename, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Product Name", "Price", "Old Price", "Discount"])
    writer.writerows(products_list)

print(f"✅ Data saved to {csv_filename}")
# Out:
# Scraping page 1/23...
# Scraping page 2/23...
# Scraping page 3/23...
# Scraping page 4/23...
# Scraping page 5/23...
# Scraping page 6/23...
# Scraping page 7/23...
# Scraping page 8/23...
# Scraping page 9/23...
# Scraping page 10/23...
# Scraping page 11/23...
# Scraping page 12/23...
# Scraping page 13/23...
# Scraping page 14/23...
# Scraping page 15/23...
# Scraping page 16/23...
# Scraping page 17/23...
# Scraping page 18/23...
# Scraping page 19/23...
# Scraping page 20/23...
# Scraping page 21/23...
# Scraping page 22/23...
# Scraping page 23/23...
# ✅ Data saved to courts_products.csv

# %% [markdown]
# #####################--This is the latest code for harvey norman

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import os
import re
from urllib.parse import urljoin

def get_product_info(product_container):
    """
    Extract product information from a single product container
    
    Args:
        product_container (BeautifulSoup): HTML element containing product info
        
    Returns:
        dict: Dictionary containing product details
    """
    product_data = {}
    
    # Extract product title and URL
    product_info_div = product_container.find('div', class_='product-info')
    if product_info_div:
        title_element = product_info_div.find('a', class_='product-title')
        if title_element:
            product_data['product_name'] = title_element.text.strip()
            product_data['product_url'] = title_element.get('href', '')
            if product_data['product_url'].startswith('//'):
                product_data['product_url'] = 'https:' + product_data['product_url']
    
    # Extract product image URL
    img_container = product_container.find('div', class_='product-image')
    if img_container:
        img_tag = img_container.find('img')
        if img_tag:
            img_url = img_tag.get('src', '')
            if img_url:
                if img_url.startswith('//'):
                    img_url = 'https:' + img_url
                product_data['image_url'] = img_url
    
    # Extract pricing information
    footer_div = product_container.find('div', class_='product-footer')
    if footer_div:
        # Current price
        price_span = footer_div.find('span', class_='price')
        if price_span:
            price_value_span = price_span.find('span', id=lambda x: x and x.startswith('sec_discounted_price_'))
            if price_value_span:
                product_data['current_price'] = f"S${price_value_span.text.strip()}"
        
        # Original/Was price
        old_price_span = footer_div.find('span', class_='price-old')
        if old_price_span:
            old_price_value_span = old_price_span.find('span', id=lambda x: x and x.startswith('sec_list_price_'))
            if old_price_value_span:
                product_data['original_price'] = f"S${old_price_value_span.text.strip()}"
    
    # Calculate discount percentage if both prices exist
    if 'current_price' in product_data and 'original_price' in product_data:
        try:
            current = float(product_data['current_price'].replace('S$', '').replace(',', ''))
            original = float(product_data['original_price'].replace('S$', '').replace(',', ''))
            if original > 0:
                discount = ((original - current) / original) * 100
                product_data['discount_percentage'] = f"{discount:.2f}%"
        except (ValueError, TypeError):
            pass
    
    return product_data

def get_next_page_url(soup, current_url):
    """
    Find the URL of the next page
    
    Args:
        soup (BeautifulSoup): Parsed HTML of the current page
        current_url (str): URL of the current page
        
    Returns:
        str or None: URL of the next page or None if not found
    """
    # Method 1: Look for pagination links
    pagination = soup.find('div', class_='ty-pagination')
    if pagination:
        next_link = pagination.find('a', class_='ty-pagination__next')
        if next_link and 'href' in next_link.attrs:
            next_page_url = next_link['href']
            if next_page_url.startswith('//'):
                next_page_url = 'https:' + next_page_url
            return next_page_url
    
    # Method 2: Check if the current URL has a page parameter and increment it
    if '/page-' in current_url:
        # Extract the current page number
        match = re.search(r'/page-(\d+)', current_url)
        if match:
            current_page = int(match.group(1))
            next_page = current_page + 1
            next_url = current_url.replace(f'/page-{current_page}', f'/page-{next_page}')
            return next_url
    
    # Method 3: If this is the first page, append page-2
    if '/page-' not in current_url:
        # Check if URL ends with / or not
        if current_url.endswith('/'):
            next_url = f"{current_url}page-2/"
        else:
            next_url = f"{current_url}/page-2/"
        return next_url
    
    return None

def check_if_page_has_products(soup):
    """
    Check if the page has any products
    
    Args:
        soup (BeautifulSoup): Parsed HTML of the page
        
    Returns:
        bool: True if the page has products, False otherwise
    """
    # Method 1: Check for product-info divs
    product_info_divs = soup.find_all('div', class_='product-info')
    if product_info_divs:
        return True
    
    # Method 2: Check for grid items
    grid_items = soup.find_all('div', class_='ty-grid-list__item')
    if grid_items:
        return True
    
    # Method 3: Check for empty category/no products message
    empty_msg = soup.find('p', class_='ty-no-items')
    if empty_msg:
        return False
    
    return False

def scrape_page(url, headers):
    """
    Scrape a single page of the Harvey Norman website
    
    Args:
        url (str): URL of the page to scrape
        headers (dict): HTTP headers for the request
        
    Returns:
        tuple: (list of product dictionaries, next page URL or None, has_products)
    """
    try:
        print(f"Scraping: {url}")
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Check if the page has products
        has_products = check_if_page_has_products(soup)
        if not has_products:
            print("No products found on this page")
            return [], None, False
        
        products = []
        
        # Find all product containers - look for the grid items first
        product_containers = soup.find_all('div', class_='ty-grid-list__item')
        
        # If no grid items found, try another approach with the structure from the HTML snippet
        if not product_containers:
            # Find divs that contain product-image, bx, and product-footer
            container_candidates = soup.find_all('div')
            for div in container_candidates:
                if (div.find('div', class_='product-image') and 
                    div.find('div', class_='bx') and 
                    div.find('div', class_='product-footer')):
                    product_containers.append(div)
        
        print(f"Found {len(product_containers)} product containers")
        
        # Extract product information from each container
        for container in product_containers:
            product_data = get_product_info(container)
            if product_data and 'product_name' in product_data:
                products.append(product_data)
        
        # Get the URL for the next page
        next_page_url = get_next_page_url(soup, url)
        
        return products, next_page_url, True
    
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return [], None, False

def scrape_all_pages(start_url, max_pages=100):
    """
    Scrape multiple pages from Harvey Norman
    
    Args:
        start_url (str): URL to start scraping from
        max_pages (int): Maximum number of pages to scrape
        
    Returns:
        pd.DataFrame: DataFrame containing all scraped product data
    """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'en-US,en;q=0.9',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.harveynorman.com.sg/'
    }
    
    all_products = []
    current_url = start_url
    page_count = 1
    
    while current_url and page_count <= max_pages:
        products, next_page_url, has_products = scrape_page(current_url, headers)
        
        if products:
            all_products.extend(products)
            print(f"Page {page_count}: Scraped {len(products)} products. Total so far: {len(all_products)}")
        
        if not has_products or not next_page_url:
            print("No more products or next page found. Scraping complete.")
            break
        
        # Update for next iteration
        current_url = next_page_url
        page_count += 1
        
        # Add a delay to avoid overwhelming the server
        time.sleep(random.uniform(1.5, 3))
    
    # Convert to DataFrame
    df = pd.DataFrame(all_products)
    
    # Remove duplicates if any
    if not df.empty and 'product_url' in df.columns:
        df = df.drop_duplicates(subset=['product_url'])
    
    return df

def main():
    """Main function to run the scraper"""
    base_url = "https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/"
    max_pages = 100
    
    print(f"Starting to scrape Harvey Norman Singapore promotions up to {max_pages} pages")
    
    # Create output directory
    os.makedirs("harvey_norman_data", exist_ok=True)
    
    # Scrape all pages
    df = scrape_all_pages(base_url, max_pages)
    
    if df.empty:
        print("No products were found.")
        return
    
    # Save to CSV
    timestamp = time.strftime("%Y%m%d-%H%M%S")
    output_file = f"harvey_norman_data/harvey_norman_products_{timestamp}.csv"
    df.to_csv(output_file, index=False)
    
    print(f"Scraping complete! Found {len(df)} unique products.")
    print(f"Data saved to {output_file}")
    
    # Print a sample of the data
    print("\nSample of scraped data:")
    print(df.head())

if __name__ == "__main__":
    main()
# Out:
# Starting to scrape Harvey Norman Singapore promotions up to 100 pages
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/
# Found 54 product containers
# Page 1: Scraped 54 products. Total so far: 54
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-2/
# Found 54 product containers
# Page 2: Scraped 54 products. Total so far: 108
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-3/
# Found 54 product containers
# Page 3: Scraped 54 products. Total so far: 162
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-4/
# Found 54 product containers
# Page 4: Scraped 54 products. Total so far: 216
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-5/
# Found 54 product containers
# Page 5: Scraped 54 products. Total so far: 270
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-6/
# Found 54 product containers
# Page 6: Scraped 54 products. Total so far: 324
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-7/
# Found 54 product containers
# Page 7: Scraped 54 products. Total so far: 378
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-8/
# Found 54 product containers
# Page 8: Scraped 54 products. Total so far: 432
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-9/
# Found 54 product containers
# Page 9: Scraped 54 products. Total so far: 486
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-10/
# Found 54 product containers
# Page 10: Scraped 54 products. Total so far: 540
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-11/
# Found 54 product containers
# Page 11: Scraped 54 products. Total so far: 594
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-12/
# Found 54 product containers
# Page 12: Scraped 54 products. Total so far: 648
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-13/
# Found 54 product containers
# Page 13: Scraped 54 products. Total so far: 702
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-14/
# Found 54 product containers
# Page 14: Scraped 54 products. Total so far: 756
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-15/
# Found 54 product containers
# Page 15: Scraped 54 products. Total so far: 810
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-16/
# Found 54 product containers
# Page 16: Scraped 54 products. Total so far: 864
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-17/
# Found 54 product containers
# Page 17: Scraped 54 products. Total so far: 918
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-18/
# Found 54 product containers
# Page 18: Scraped 54 products. Total so far: 972
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-19/
# Found 54 product containers
# Page 19: Scraped 54 products. Total so far: 1026
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-20/
# Found 54 product containers
# Page 20: Scraped 54 products. Total so far: 1080
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-21/
# Found 54 product containers
# Page 21: Scraped 54 products. Total so far: 1134
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-22/
# Found 54 product containers
# Page 22: Scraped 54 products. Total so far: 1188
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-23/
# Found 54 product containers
# Page 23: Scraped 54 products. Total so far: 1242
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-24/
# Found 54 product containers
# Page 24: Scraped 54 products. Total so far: 1296
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-25/
# Found 54 product containers
# Page 25: Scraped 54 products. Total so far: 1350
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-26/
# Found 54 product containers
# Page 26: Scraped 54 products. Total so far: 1404
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-27/
# Found 54 product containers
# Page 27: Scraped 54 products. Total so far: 1458
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-28/
# Found 54 product containers
# Page 28: Scraped 54 products. Total so far: 1512
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-29/
# Found 54 product containers
# Page 29: Scraped 54 products. Total so far: 1566
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-30/
# Found 54 product containers
# Page 30: Scraped 54 products. Total so far: 1620
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-31/
# Found 54 product containers
# Page 31: Scraped 54 products. Total so far: 1674
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-32/
# Found 54 product containers
# Page 32: Scraped 54 products. Total so far: 1728
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-33/
# Found 54 product containers
# Page 33: Scraped 54 products. Total so far: 1782
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-34/
# Found 54 product containers
# Page 34: Scraped 54 products. Total so far: 1836
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-35/
# Found 54 product containers
# Page 35: Scraped 54 products. Total so far: 1890
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-36/
# Found 54 product containers
# Page 36: Scraped 54 products. Total so far: 1944
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-37/
# Found 54 product containers
# Page 37: Scraped 54 products. Total so far: 1998
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-38/
# Found 54 product containers
# Page 38: Scraped 54 products. Total so far: 2052
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-39/
# Found 54 product containers
# Page 39: Scraped 54 products. Total so far: 2106
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-40/
# Found 54 product containers
# Page 40: Scraped 54 products. Total so far: 2160
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-41/
# Found 54 product containers
# Page 41: Scraped 54 products. Total so far: 2214
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-42/
# Found 54 product containers
# Page 42: Scraped 54 products. Total so far: 2268
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-43/
# Found 54 product containers
# Page 43: Scraped 54 products. Total so far: 2322
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-44/
# Found 54 product containers
# Page 44: Scraped 54 products. Total so far: 2376
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-45/
# Found 54 product containers
# Page 45: Scraped 54 products. Total so far: 2430
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-46/
# Found 54 product containers
# Page 46: Scraped 54 products. Total so far: 2484
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-47/
# Found 54 product containers
# Page 47: Scraped 54 products. Total so far: 2538
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-48/
# Found 54 product containers
# Page 48: Scraped 54 products. Total so far: 2592
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-49/
# Found 54 product containers
# Page 49: Scraped 54 products. Total so far: 2646
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-50/
# Found 54 product containers
# Page 50: Scraped 54 products. Total so far: 2700
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-51/
# Found 54 product containers
# Page 51: Scraped 54 products. Total so far: 2754
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-52/
# Found 54 product containers
# Page 52: Scraped 54 products. Total so far: 2808
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-53/
# Found 54 product containers
# Page 53: Scraped 54 products. Total so far: 2862
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-54/
# Found 54 product containers
# Page 54: Scraped 54 products. Total so far: 2916
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-55/
# Found 54 product containers
# Page 55: Scraped 54 products. Total so far: 2970
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-56/
# Found 54 product containers
# Page 56: Scraped 54 products. Total so far: 3024
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-57/
# Found 54 product containers
# Page 57: Scraped 54 products. Total so far: 3078
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-58/
# Found 54 product containers
# Page 58: Scraped 54 products. Total so far: 3132
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-59/
# Found 52 product containers
# Page 59: Scraped 52 products. Total so far: 3184
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-60/
# Found 52 product containers
# Page 60: Scraped 52 products. Total so far: 3236
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-61/
# Found 54 product containers
# Page 61: Scraped 54 products. Total so far: 3290
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-62/
# Found 54 product containers
# Page 62: Scraped 54 products. Total so far: 3344
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-63/
# Found 54 product containers
# Page 63: Scraped 54 products. Total so far: 3398
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-64/
# Found 54 product containers
# Page 64: Scraped 54 products. Total so far: 3452
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-65/
# Found 54 product containers
# Page 65: Scraped 54 products. Total so far: 3506
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-66/
# Found 54 product containers
# Page 66: Scraped 54 products. Total so far: 3560
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-67/
# Found 54 product containers
# Page 67: Scraped 54 products. Total so far: 3614
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-68/
# Found 54 product containers
# Page 68: Scraped 54 products. Total so far: 3668
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-69/
# Found 54 product containers
# Page 69: Scraped 54 products. Total so far: 3722
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-70/
# Found 54 product containers
# Page 70: Scraped 54 products. Total so far: 3776
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-71/
# Found 54 product containers
# Page 71: Scraped 54 products. Total so far: 3830
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-72/
# Found 54 product containers
# Page 72: Scraped 54 products. Total so far: 3884
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-73/
# Found 54 product containers
# Page 73: Scraped 54 products. Total so far: 3938
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-74/
# Found 54 product containers
# Page 74: Scraped 54 products. Total so far: 3992
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-75/
# Found 54 product containers
# Page 75: Scraped 54 products. Total so far: 4046
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-76/
# Found 54 product containers
# Page 76: Scraped 54 products. Total so far: 4100
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-77/
# Found 54 product containers
# Page 77: Scraped 54 products. Total so far: 4154
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-78/
# Found 54 product containers
# Page 78: Scraped 54 products. Total so far: 4208
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-79/
# Found 54 product containers
# Page 79: Scraped 54 products. Total so far: 4262
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-80/
# Found 54 product containers
# Page 80: Scraped 54 products. Total so far: 4316
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-81/
# Found 54 product containers
# Page 81: Scraped 54 products. Total so far: 4370
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-82/
# Found 54 product containers
# Page 82: Scraped 54 products. Total so far: 4424
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-83/
# Found 54 product containers
# Page 83: Scraped 54 products. Total so far: 4478
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-84/
# Found 54 product containers
# Page 84: Scraped 54 products. Total so far: 4532
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-85/
# Found 54 product containers
# Page 85: Scraped 54 products. Total so far: 4586
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-86/
# Found 54 product containers
# Page 86: Scraped 54 products. Total so far: 4640
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-87/
# Found 54 product containers
# Page 87: Scraped 54 products. Total so far: 4694
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-88/
# Found 54 product containers
# Page 88: Scraped 54 products. Total so far: 4748
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-89/
# Found 54 product containers
# Page 89: Scraped 54 products. Total so far: 4802
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-90/
# Found 54 product containers
# Page 90: Scraped 54 products. Total so far: 4856
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-91/
# Found 54 product containers
# Page 91: Scraped 54 products. Total so far: 4910
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-92/
# Found 54 product containers
# Page 92: Scraped 54 products. Total so far: 4964
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-93/
# Found 54 product containers
# Page 93: Scraped 54 products. Total so far: 5018
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-94/
# Found 54 product containers
# Page 94: Scraped 54 products. Total so far: 5072
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-95/
# Found 54 product containers
# Page 95: Scraped 54 products. Total so far: 5126
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-96/
# Found 54 product containers
# Page 96: Scraped 54 products. Total so far: 5180
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-97/
# Found 54 product containers
# Page 97: Scraped 54 products. Total so far: 5234
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-98/
# Found 54 product containers
# Page 98: Scraped 54 products. Total so far: 5288
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-99/
# Found 54 product containers
# Page 99: Scraped 54 products. Total so far: 5342
# Scraping: https://www.harveynorman.com.sg/promotions-en/harvey-raya-sale-2025-en/page-100/
# Found 54 product containers
# Page 100: Scraped 54 products. Total so far: 5396
# Scraping complete! Found 1998 unique products.
# Data saved to harvey_norman_data/harvey_norman_products_20250316-114221.csv
#
# Sample of scraped data:
#                                          product_name  \
# 0   LG (GT-T5107BM) 506L Top Freezer with Inverter...
# 16     LG FV1410H3BA Front Load Washer Dryer (10/6KG)
# 18  LG AI Direct Drive FV1409S4W 9kg Front Load Wa...
# 20     LG FV1411S2B Front Load Washing Machine (11KG)
# 22  LG Front Control Smart Wi-fi Enabled Dishwashe...
#
#                                           product_url  \
# 0   https://www.harveynorman.com.sg/home-appliance...
# 16  https://www.harveynorman.com.sg/home-appliance...
# 18  https://www.harveynorman.com.sg/home-appliance...
# 20  https://www.harveynorman.com.sg/home-appliance...
# 22  https://www.harveynorman.com.sg/home-appliance...
#
#                                             image_url current_price  \
# 0   https://hnsgsfp.imgix.net/4/images/detailed/15...       S$1,299
# 16  https://hnsgsfp.imgix.net/4/images/detailed/15...       S$1,449
# 18  https://hnsgsfp.imgix.net/4/images/detailed/15...         S$869
# 20  https://hnsgsfp.imgix.net/4/images/detailed/15...       S$1,399
# 22  https://hnsgsfp.imgix.net/4/images/detailed/15...         S$999
#
#    original_price discount_percentage
# 0         S$1,650              21.27%
# 16        S$1,935              25.12%
# 18        S$1,151              24.50%
# 20        S$1,833              23.68%
# 22        S$1,299              23.09%
